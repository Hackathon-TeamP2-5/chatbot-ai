# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.4 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
import pandas as pd
import os

os.environ["HF_TOKEN"] = "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"

# Login using the Hugging Face CLI first: `huggingface-cli login`
# Then, load the dataset using the `load_dataset` function
dataset = load_dataset("Amod/mental_health_counseling_conversations")

# Convert the dataset to a pandas DataFrame
df = dataset["train"].to_pandas()

print(df.head())
# Out:
# README.md:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# combined_dataset.json:   0%|          | 0.00/4.79M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3512 [00:00<?, ? examples/s]
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Response
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Colab Notebooks/Hackathon-TeamP2-5/dataset.csv'  # Change 'YourFolderName' to your desired path
df.to_csv(path, index=False)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# List files in the specific directory of your Google Drive
folder_path = '/content/drive/My Drive/Colab Notebooks/Hackathon-TeamP2-5'
files_in_folder = os.listdir(folder_path)
print(files_in_folder)
# Out:
# ['processed_dataset.csv', 'model.ipynb', 'dataset.csv', 'dataset.gsheet', 'test.ipynb', 'analysis.ipynb', 'data_preparation.ipynb']

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Hackathon-TeamP2-5/dataset.csv')  # Loading from CSV

print(df.head()[0:5])
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Context2  \
# 0  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 1  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 2  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 3  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 4  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
#
#                                             Response  \
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# ...

# %%
# Reshaping the DataFrame to interleave Arabic and English contexts & responses
context_combined = df[['Context', 'Context2']].stack().reset_index(drop=True)
response_combined = df[['Response', 'Response2']].stack().reset_index(drop=True)

# Creating the final shuffled DataFrame
df_final = pd.DataFrame({'Context': context_combined, 'Response': response_combined})

# Display the first few rows of the reshuffled DataFrame
print(df_final.head())
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 2  I'm going through some things with my feelings...
# 3  أمر ببعض الأمور بمشاعري ونفسي. بالكاد أنام ولا...
# 4  I'm going through some things with my feelings...
#
#                                             Response
# 0  If everyone thinks you're worthless, then mayb...
# 1  إذا كان الجميع يعتقد أنك عديم القيمة، فربما تح...
# 2  Hello, and thank you for your question and see...
# 3  مرحبًا، وشكراً لك على سؤالك وطلب النصيحة في هذ...
# 4  First thing I'd suggest is getting the sleep y...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# List files in the specific directory of your Google Drive
folder_path = '/content/drive/My Drive/Colab Notebooks/Hackathon-TeamP2-5'
files_in_folder = os.listdir(folder_path)
print(files_in_folder)
# Out:
# ['processed_dataset.csv', 'model.ipynb', 'dataset.csv', 'dataset.gsheet', 'test.ipynb', 'analysis.ipynb', 'data_preparation.ipynb', 'prepared_dataset.csv', 'prepared_dataset.gsheet']

# %%
path = '/content/drive/My Drive/Colab Notebooks/Hackathon-TeamP2-5/prepared_dataset.csv'
df_final.to_csv(path, index=False)
